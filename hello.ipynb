# %% [markdown]
# # Hello from LazyVim to Colab
#
# 1. Open this file in Neovim.
# 2. Run :MoltenInit then press leader-rc on the cell below.
# 3. Upload this .ipynb to Google Colab (File -> Upload notebook) and run the same cell there.

# %%
print("Hello, World!")
